# %%
#import word-press dataset
import pandas as pd
import numpy as np

file_name = 'word2vec_norm.csv'

df = pd.read_csv('./' + file_name)
df
# Out:
#                0         1         2         3         4         5         6  \
# 0       0.213186 -0.051701 -0.081564  0.095487  0.257475  0.156231  0.040088
# 1       0.253478 -0.045174 -0.242986  0.072101  0.115538  0.054672 -0.008726
# 2       0.137060  0.049778 -0.232379  0.153882 -0.088084  0.056613 -0.162745
# 3       0.096060 -0.392705 -0.089899  0.077729  0.072941  0.180241 -0.028196
# 4       0.054456  0.139461  0.011011 -0.111939  0.168293 -0.222286  0.049725
# 5       0.005639 -0.187296  0.113523 -0.088593  0.117904  0.195315 -0.127978
# 6       0.015238  0.015711 -0.276276 -0.030570  0.211719  0.050473  0.045473
# 7       0.078328 -0.059709  0.171210 -0.180715  0.218485  0.148275 -0.033051
# 8      -0.045232 -0.114527  0.007569 -0.225768  0.101335  0.045768 -0.056915
# 9       0.148646  0.068312  0.102957 -0.218331  0.108308 -0.013998 -0.041892
# 10      0.013677  0.055027 -0.033837  0.166915  0.047939 -0.023319 -0.055903
# ...

# %%
#data normalizing, used in previous version
from sklearn import preprocessing
df_vector_norm = preprocessing.normalize(df_vector, norm='l2', axis=1, copy=True, return_norm=False)
df_vector_norm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8db9ed3c8a36> in <module>
#       1 #data normalizing, used in previous version
#       2 from sklearn import preprocessing
# ----> 3 df_vector_norm = preprocessing.normalize(df_vector, norm='l2', axis=1, copy=True, return_norm=False)
#       4 df_vector_norm
#
# NameError: name 'df_vector' is not defined

# %%
#saving our normalized splitted word2vec
new_df = pd.DataFrame(df_vector_norm)
new_df.to_csv("./word2vec_norm.csv")

# %%
import numpy as np

from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler

X = StandardScaler().fit_transform(df)

# Compute DBSCAN
db = DBSCAN(eps=0.3, min_samples=3).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)

# %%
# Plot result
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Transparent used for noise.
        col = None

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-93a10265591c> in <module>
#      14
#      15     xy = X[class_member_mask & core_samples_mask]
# ---> 16     plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
#      17              markeredgecolor='k', markersize=14)
#      18
#
# TypeError: 'NoneType' object is not iterable

# %%
labels
# Out:
# array([-1, -1, -1, ..., -1, -1, 79])

# %%
new_df = df.assign(cluster = labels)
new_df = new_df.drop(['v0','v1','v2','v3','v4','v5','v6','v7','v8','v9','v10','v11','v12','v13','v14','v15','v16','v17',
    'v18','v19','v20','v21','v22','v23','v24','v25','v26','v27','v28','v29','v30','v31'], axis = 1)
new_df.to_csv("./word2vec_cluster_db2.csv")
